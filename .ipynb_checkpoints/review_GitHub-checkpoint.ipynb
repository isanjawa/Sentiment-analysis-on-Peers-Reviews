# %% [markdown]
# ### Capstone project: Sentiment analysis on scientific papers reviews.

# %%
# !pip install fsspec
# !pip install -U spacy
# !pip install keras tensorflow
# !pip install sentiment-analysis-spanish
# !python -m spacy download es_core_news_sm
# !pip install es-lemmatizer
# !pip install spacy_spanish_lemmatizer
# Out:
# Requirement already satisfied: fsspec in c:\users\isanj\anaconda3\lib\site-packages (0.8.3)
# Requirement already up-to-date: spacy in c:\users\isanj\anaconda3\lib\site-packages (3.0.3)
# Requirement already satisfied, skipping upgrade: spacy-legacy<3.1.0,>=3.0.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy) (3.0.1)
# Requirement already satisfied, skipping upgrade: pathy in c:\users\isanj\anaconda3\lib\site-packages (from spacy) (0.4.0)
# Requirement already satisfied, skipping upgrade: cymem<2.1.0,>=2.0.2 in c:\users\isanj\anaconda3\lib\site-packages (from spacy) (2.0.5)
# Requirement already satisfied, skipping upgrade: catalogue<2.1.0,>=2.0.1 in c:\users\isanj\anaconda3\lib\site-packages (from spacy) (2.0.1)
# Requirement already satisfied, skipping upgrade: preshed<3.1.0,>=3.0.2 in c:\users\isanj\anaconda3\lib\site-packages (from spacy) (3.0.5)
# Requirement already satisfied, skipping upgrade: srsly<3.0.0,>=2.4.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy) (2.4.0)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy) (20.4)
# Requirement already satisfied, skipping upgrade: wasabi<1.1.0,>=0.8.1 in c:\users\isanj\anaconda3\lib\site-packages (from spacy) (0.8.2)
# Requirement already satisfied, skipping upgrade: murmurhash<1.1.0,>=0.28.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy) (1.19.2)
# Requirement already satisfied, skipping upgrade: blis<0.8.0,>=0.4.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy) (0.7.4)
# Requirement already satisfied, skipping upgrade: tqdm<5.0.0,>=4.38.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy) (4.50.2)
# Requirement already satisfied, skipping upgrade: typer<0.4.0,>=0.3.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy) (0.3.2)
# Requirement already satisfied, skipping upgrade: setuptools in c:\users\isanj\anaconda3\lib\site-packages (from spacy) (50.3.1.post20201107)
# Requirement already satisfied, skipping upgrade: pydantic<1.8.0,>=1.7.1 in c:\users\isanj\anaconda3\lib\site-packages (from spacy) (1.7.3)
# Requirement already satisfied, skipping upgrade: jinja2 in c:\users\isanj\anaconda3\lib\site-packages (from spacy) (2.11.2)
# Requirement already satisfied, skipping upgrade: requests<3.0.0,>=2.13.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy) (2.24.0)
# Requirement already satisfied, skipping upgrade: thinc<8.1.0,>=8.0.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy) (8.0.1)
# Requirement already satisfied, skipping upgrade: smart-open<4.0.0,>=2.2.0 in c:\users\isanj\anaconda3\lib\site-packages (from pathy->spacy) (3.0.0)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in c:\users\isanj\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied, skipping upgrade: six in c:\users\isanj\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (1.15.0)
# Requirement already satisfied, skipping upgrade: click<7.2.0,>=7.1.1 in c:\users\isanj\anaconda3\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in c:\users\isanj\anaconda3\lib\site-packages (from jinja2->spacy) (1.1.1)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in c:\users\isanj\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\isanj\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.25.11)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in c:\users\isanj\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\isanj\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.6.20)
# Requirement already satisfied: keras in c:\users\isanj\anaconda3\lib\site-packages (2.4.3)
# Requirement already satisfied: tensorflow in c:\users\isanj\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: pyyaml in c:\users\isanj\anaconda3\lib\site-packages (from keras) (5.3.1)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\isanj\anaconda3\lib\site-packages (from keras) (1.19.2)
# Requirement already satisfied: scipy>=0.14 in c:\users\isanj\anaconda3\lib\site-packages (from keras) (1.5.2)
# Requirement already satisfied: h5py in c:\users\isanj\anaconda3\lib\site-packages (from keras) (2.10.0)
# Requirement already satisfied: gast==0.3.3 in c:\users\isanj\anaconda3\lib\site-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: tensorboard~=2.4 in c:\users\isanj\anaconda3\lib\site-packages (from tensorflow) (2.4.1)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\isanj\anaconda3\lib\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\isanj\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\isanj\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: six~=1.15.0 in c:\users\isanj\anaconda3\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: wheel~=0.35 in c:\users\isanj\anaconda3\lib\site-packages (from tensorflow) (0.35.1)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\isanj\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\isanj\anaconda3\lib\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: grpcio~=1.32.0 in c:\users\isanj\anaconda3\lib\site-packages (from tensorflow) (1.32.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\isanj\anaconda3\lib\site-packages (from tensorflow) (3.15.4)
# Requirement already satisfied: absl-py~=0.10 in c:\users\isanj\anaconda3\lib\site-packages (from tensorflow) (0.11.0)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\isanj\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in c:\users\isanj\anaconda3\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\isanj\anaconda3\lib\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\isanj\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\isanj\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (2.24.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\isanj\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (0.4.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\isanj\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.27.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\isanj\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\isanj\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.8.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\isanj\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (50.3.1.post20201107)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\isanj\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow) (1.0.1)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\isanj\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\isanj\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\isanj\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\isanj\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (3.0.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\isanj\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (1.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\isanj\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\isanj\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\isanj\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\isanj\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\isanj\anaconda3\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.4.8)
# Requirement already satisfied: sentiment-analysis-spanish in c:\users\isanj\anaconda3\lib\site-packages (0.0.25)
# Requirement already satisfied: es-core-news-sm==3.0.0 from https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.0.0/es_core_news_sm-3.0.0-py3-none-any.whl#egg=es_core_news_sm==3.0.0 in c:\users\isanj\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in c:\users\isanj\anaconda3\lib\site-packages (from es-core-news-sm==3.0.0) (3.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (2.24.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (4.50.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\isanj\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (0.8.2)
# Requirement already satisfied: pathy in c:\users\isanj\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (0.4.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (3.0.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (2.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\isanj\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (3.0.5)
# Requirement already satisfied: jinja2 in c:\users\isanj\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (2.11.2)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (0.3.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (20.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\isanj\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (2.0.5)
# Requirement already satisfied: setuptools in c:\users\isanj\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (50.3.1.post20201107)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (1.19.2)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (0.7.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in c:\users\isanj\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (2.0.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (8.0.1)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in c:\users\isanj\anaconda3\lib\site-packages (from spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (1.7.3)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\isanj\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\isanj\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\isanj\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\isanj\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (2.10)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in c:\users\isanj\anaconda3\lib\site-packages (from pathy->spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (3.0.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\isanj\anaconda3\lib\site-packages (from jinja2->spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (1.1.1)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\isanj\anaconda3\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (7.1.2)
# Requirement already satisfied: six in c:\users\isanj\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\isanj\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->es-core-news-sm==3.0.0) (2.4.7)
# [+] Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')
# 2021-03-07 13:25:07.375866: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2021-03-07 13:25:07.376380: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Requirement already satisfied: es-lemmatizer in c:\users\isanj\anaconda3\lib\site-packages (0.2.1)
# Requirement already satisfied: spacy_spanish_lemmatizer in c:\users\isanj\anaconda3\lib\site-packages (0.6)
# Requirement already satisfied: spacy>=3.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy_spanish_lemmatizer) (3.0.3)
# Requirement already satisfied: jinja2 in c:\users\isanj\anaconda3\lib\site-packages (from spacy>=3.0->spacy_spanish_lemmatizer) (2.11.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy>=3.0->spacy_spanish_lemmatizer) (20.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\isanj\anaconda3\lib\site-packages (from spacy>=3.0->spacy_spanish_lemmatizer) (0.8.2)
# Requirement already satisfied: pathy in c:\users\isanj\anaconda3\lib\site-packages (from spacy>=3.0->spacy_spanish_lemmatizer) (0.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy>=3.0->spacy_spanish_lemmatizer) (4.50.2)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy>=3.0->spacy_spanish_lemmatizer) (1.19.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy>=3.0->spacy_spanish_lemmatizer) (8.0.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy>=3.0->spacy_spanish_lemmatizer) (2.4.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy>=3.0->spacy_spanish_lemmatizer) (1.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy>=3.0->spacy_spanish_lemmatizer) (2.24.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in c:\users\isanj\anaconda3\lib\site-packages (from spacy>=3.0->spacy_spanish_lemmatizer) (2.0.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\isanj\anaconda3\lib\site-packages (from spacy>=3.0->spacy_spanish_lemmatizer) (3.0.5)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in c:\users\isanj\anaconda3\lib\site-packages (from spacy>=3.0->spacy_spanish_lemmatizer) (1.7.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy>=3.0->spacy_spanish_lemmatizer) (0.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy>=3.0->spacy_spanish_lemmatizer) (3.0.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\isanj\anaconda3\lib\site-packages (from spacy>=3.0->spacy_spanish_lemmatizer) (2.0.5)
# Requirement already satisfied: setuptools in c:\users\isanj\anaconda3\lib\site-packages (from spacy>=3.0->spacy_spanish_lemmatizer) (50.3.1.post20201107)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in c:\users\isanj\anaconda3\lib\site-packages (from spacy>=3.0->spacy_spanish_lemmatizer) (0.3.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\isanj\anaconda3\lib\site-packages (from jinja2->spacy>=3.0->spacy_spanish_lemmatizer) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\isanj\anaconda3\lib\site-packages (from packaging>=20.0->spacy>=3.0->spacy_spanish_lemmatizer) (2.4.7)
# Requirement already satisfied: six in c:\users\isanj\anaconda3\lib\site-packages (from packaging>=20.0->spacy>=3.0->spacy_spanish_lemmatizer) (1.15.0)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in c:\users\isanj\anaconda3\lib\site-packages (from pathy->spacy>=3.0->spacy_spanish_lemmatizer) (3.0.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\isanj\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->spacy_spanish_lemmatizer) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\isanj\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->spacy_spanish_lemmatizer) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\isanj\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->spacy_spanish_lemmatizer) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\isanj\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->spacy_spanish_lemmatizer) (2020.6.20)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in c:\users\isanj\anaconda3\lib\site-packages (from typer<0.4.0,>=0.3.0->spacy>=3.0->spacy_spanish_lemmatizer) (7.1.2)

# %%
#https://pypi.org/project/sentiment-analysis-spanish/
import pandas as pd
import numpy as np
import nltk
import json
import string
from sentiment_analysis_spanish import sentiment_analysis

from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
stop_words = set(stopwords.words('spanish'))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\isanj\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\isanj\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\isanj\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\isanj\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Load the data file

with open('C://Users//isanj//Downloads//reviews.json', encoding="UTF-8") as f:
    data = json.load(f)    
    
#print(data)

# %%
# Create a dataframe

reviews_df= pd.DataFrame.from_dict(data) 
  
reviews_df.head()
# Out:
#                                                paper
# 0  {'id': 1, 'preliminary_decision': 'accept', 'r...
# 1  {'id': 2, 'preliminary_decision': 'accept', 'r...
# 2  {'id': 3, 'preliminary_decision': 'accept', 'r...
# 3  {'id': 4, 'preliminary_decision': 'accept', 'r...
# 4  {'id': 5, 'preliminary_decision': 'accept', 'r...

# %%
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.json_normalize.html

# Split a column into multiple columns
df2 = pd.json_normalize(reviews_df['paper'])
df2
# Out:
#       id preliminary_decision  \
# 0      1               accept
# 1      2               accept
# 2      3               accept
# 3      4               accept
# 4      5               accept
# ..   ...                  ...
# 167  168               accept
# 168  169               accept
# 169  170               reject
# 170  171               accept
# 171  172          no decision
#
#                                                 review
# 0    [{'confidence': '4', 'evaluation': '1', 'id': ...
# 1    [{'confidence': '4', 'evaluation': '2', 'id': ...
# 2    [{'confidence': '4', 'evaluation': '2', 'id': ...
# 3    [{'confidence': '4', 'evaluation': '2', 'id': ...
# 4    [{'confidence': '4', 'evaluation': '2', 'id': ...
# ..                                                 ...
# 167  [{'confidence': '3', 'evaluation': '2', 'id': ...
# 168  [{'confidence': '3', 'evaluation': '1', 'id': ...
# 169  [{'confidence': '5', 'evaluation': '-1', 'id':...
# 170  [{'confidence': '4', 'evaluation': '-1', 'id':...
# 171  [{'confidence': '4', 'evaluation': '1', 'id': ...
#
# [172 rows x 3 columns]

# %%
# Rename the "id" column as "book_id"

df2.rename(columns={'id':'book_id'}, inplace=True)
df2
# Out:
#      book_id preliminary_decision  \
# 0          1               accept
# 1          2               accept
# 2          3               accept
# 3          4               accept
# 4          5               accept
# ..       ...                  ...
# 167      168               accept
# 168      169               accept
# 169      170               reject
# 170      171               accept
# 171      172          no decision
#
#                                                 review
# 0    [{'confidence': '4', 'evaluation': '1', 'id': ...
# 1    [{'confidence': '4', 'evaluation': '2', 'id': ...
# 2    [{'confidence': '4', 'evaluation': '2', 'id': ...
# 3    [{'confidence': '4', 'evaluation': '2', 'id': ...
# 4    [{'confidence': '4', 'evaluation': '2', 'id': ...
# ..                                                 ...
# 167  [{'confidence': '3', 'evaluation': '2', 'id': ...
# 168  [{'confidence': '3', 'evaluation': '1', 'id': ...
# 169  [{'confidence': '5', 'evaluation': '-1', 'id':...
# 170  [{'confidence': '4', 'evaluation': '-1', 'id':...
# 171  [{'confidence': '4', 'evaluation': '1', 'id': ...
#
# [172 rows x 3 columns]

# %%
# Check for NaN under an entire DataFrame
df2.isnull().values.any()
# Out:
# False

# %%
# Extracting just the 'review' column

column = ['review']
df3 = pd.DataFrame(df2, columns=column)
df3
# Out:
#                                                 review
# 0    [{'confidence': '4', 'evaluation': '1', 'id': ...
# 1    [{'confidence': '4', 'evaluation': '2', 'id': ...
# 2    [{'confidence': '4', 'evaluation': '2', 'id': ...
# 3    [{'confidence': '4', 'evaluation': '2', 'id': ...
# 4    [{'confidence': '4', 'evaluation': '2', 'id': ...
# ..                                                 ...
# 167  [{'confidence': '3', 'evaluation': '2', 'id': ...
# 168  [{'confidence': '3', 'evaluation': '1', 'id': ...
# 169  [{'confidence': '5', 'evaluation': '-1', 'id':...
# 170  [{'confidence': '4', 'evaluation': '-1', 'id':...
# 171  [{'confidence': '4', 'evaluation': '1', 'id': ...
#
# [172 rows x 1 columns]

# %%
# Use stack to unlist the list the column 'review'
df4 = df3.apply(lambda x: x.apply(pd.Series).stack()).reset_index().drop('level_1', 1)
df4
# Out:
#      level_0                                             review
# 0          0  {'confidence': '4', 'evaluation': '1', 'id': 1...
# 1          0  {'confidence': '4', 'evaluation': '1', 'id': 2...
# 2          0  {'confidence': '5', 'evaluation': '1', 'id': 3...
# 3          1  {'confidence': '4', 'evaluation': '2', 'id': 1...
# 4          1  {'confidence': '4', 'evaluation': '2', 'id': 2...
# ..       ...                                                ...
# 400      169  {'confidence': '5', 'evaluation': '-1', 'id': ...
# 401      169  {'confidence': '4', 'evaluation': '-1', 'id': ...
# 402      170  {'confidence': '4', 'evaluation': '-1', 'id': ...
# 403      170  {'confidence': '3', 'evaluation': '1', 'id': 2...
# 404      171  {'confidence': '4', 'evaluation': '1', 'id': 1...
#
# [405 rows x 2 columns]

# %%
# Use concat to unnest the dictionary and put it into seperate columns
df4 =  pd.concat([df4, df4['review'].apply(pd.Series), df4.drop('review', axis=1, inplace = True)], axis=1)
df4
# Out:
#      level_0 confidence evaluation  id lan orientation remarks  \
# 0          0          4          1   1  es           0
# 1          0          4          1   2  es           1
# 2          0          5          1   3  es           1
# 3          1          4          2   1  es           1
# 4          1          4          2   2  es           0
# ..       ...        ...        ...  ..  ..         ...     ...
# 400      169          5         -1   1  es          -2
# 401      169          4         -1   2  es          -1
# 402      170          4         -1   1  es           0
# 403      170          3          1   2  es          -1
# 404      171          4          1   1  es          -1
#
#                                                   text    timespan
# 0    - El artículo aborda un problema contingente y...  2010-07-05
# 1    El artículo presenta recomendaciones prácticas...  2010-07-05
# 2    - El tema es muy interesante y puede ser de mu...  2010-07-05
# 3    Se explica en forma ordenada y didáctica una e...  2010-07-05
# 4                                                       2010-07-05
# ..                                                 ...         ...
# 400  El trabajo pretende ofrecer una visión del uso...  2015-07-05
# 401  El paper está bien escrito y de fácil lectura....  2015-07-05
# 402  Observación de fondo:  No se presenta un ejemp...  2015-07-05
# 403  Se propone un procedimiento para elaborar máqu...  2015-07-05
# 404  El artículo describe básicamente los component...  2015-07-05
#
# [405 rows x 9 columns]

# %%
# # Use concat to unnest the dictionary and put it into seperate columns
# df4 = pd.concat([df3.drop('review', axis=1, inplace = True), df4['review'].apply(pd.Series)], axis=1)
# df4

# %%
#get the dataframe columns
cols = df4.columns 

#print the columns' names
#print(cols)

# %%
# Check for NaN under an entire DataFrame
df4.isnull().values.any()
# Out:
# True

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 405 entries, 0 to 404
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   level_0      405 non-null    int64
#  1   confidence   403 non-null    object
#  2   evaluation   405 non-null    object
#  3   id           405 non-null    int64
#  4   lan          405 non-null    object
#  5   orientation  405 non-null    object
#  6   remarks      405 non-null    object
#  7   text         405 non-null    object
#  8   timespan     405 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 28.6+ KB

# %% [markdown]
# ### Extract reviews based on the language

# %%
df4.head()
# Out:
#    level_0 confidence evaluation  id lan orientation remarks  \
# 0        0          4          1   1  es           0
# 1        0          4          1   2  es           1
# 2        0          5          1   3  es           1
# 3        1          4          2   1  es           1
# 4        1          4          2   2  es           0
#
#                                                 text    timespan
# 0  - El artículo aborda un problema contingente y...  2010-07-05
# 1  El artículo presenta recomendaciones prácticas...  2010-07-05
# 2  - El tema es muy interesante y puede ser de mu...  2010-07-05
# 3  Se explica en forma ordenada y didáctica una e...  2010-07-05
# 4                                                     2010-07-05

# %%
df4.lan.unique()
# Out:
# array(['es', 'en'], dtype=object)

# %%
# Count each unique value

df4.lan.value_counts()
# Out:
# es    388
# en     17
# Name: lan, dtype: int64

# %%
df4.groupby('lan').describe()
# Out:
#     level_0                                                           id  \
#       count       mean        std  min    25%   50%    75%    max  count
# lan
# en     17.0  58.647059  62.012036  2.0   7.00  32.0  127.0  161.0   17.0
# es    388.0  85.054124  49.054730  0.0  39.75  91.5  125.0  171.0  388.0
#
#
#          mean       std  min  25%  50%  75%  max
# lan
# en   1.882353  0.781213  1.0  1.0  2.0  2.0  3.0
# es   1.822165  0.823946  1.0  1.0  2.0  2.0  4.0

# %%
# English reviews

df4_english = df4[df4['lan']=='en']
df4_english
# Out:
#      level_0 confidence evaluation  id lan orientation  \
# 7          2          3          2   2  en           1
# 8          2          3          0   3  en          -1
# 19         7          4          1   1  en           0
# 20         7          4          2   2  en           1
# 21         7          5          1   3  en           0
# 30        11          3          2   2  en           0
# 48        18          4          2   1  en           1
# 78        29          4         -2   1  en          -1
# 88        32          4         -1   2  en          -1
# 99        37          4          2   1  en           0
# 101       37          4          1   3  en          -1
# 158       68          4          0   1  en          -1
# 309      127          4          1   3  en           0
# 356      147          3          2   2  en           1
# 366      152          3          1   2  en           0
# 367      153          4          2   1  en           1
# 384      161          3          0   2  en           0
#
#                                                remarks  \
# 7
# 8
# 19
# 20
# 21
# 30
# 48
# 78
# 88   Unless there is a strong info sci and business...
# 99
# 101
# 158
# 309  * I recommend to change the title in order to ...
# 356
# 366
# 367
# 384
#
#                                                   text    timespan
# 7    This paper aims to show new deployment alterna...  2010-07-05
# 8    The paper is well structured. It follows a log...  2010-07-05
# 19   The paper describes an experience concerning t...  2010-07-05
# 20   This manuscript addresses an interesting solut...  2010-07-05
# 21   Interesting application domain.  Nothing new f...  2010-07-05
# 30   This paper presents a software tool that is us...  2010-07-05
# 48   This paper is very interesting, I like the ide...  2010-07-05
# 78   I don't think the work reported in this paper ...  2010-07-05
# 88   Abstract: Needs to have a definition of ERP - ...  2010-07-05
# 99   The paper introduces a segmentation procedure ...  2010-07-05
# 101  The paper presents a medical test based on ima...  2010-07-05
# 158  This is a developed application to support inf...  2013-07-05
# 309  •I recommend to change the paper title in orde...  2014-07-05
# 356  The authors made an exhaustive study on public...  2015-07-05
# 366  This work gives expected results and creates a...  2015-07-05
# 367  This is an interesting article, present develo...  2015-07-05
# 384  this paper applies an advanced algorithm to ga...  2015-07-05

# %%
# Spanish reviews

df4_spanish = df4[df4['lan']=='es']
df4_spanish.head()
# Out:
#    level_0 confidence evaluation  id lan orientation remarks  \
# 0        0          4          1   1  es           0
# 1        0          4          1   2  es           1
# 2        0          5          1   3  es           1
# 3        1          4          2   1  es           1
# 4        1          4          2   2  es           0
#
#                                                 text    timespan
# 0  - El artículo aborda un problema contingente y...  2010-07-05
# 1  El artículo presenta recomendaciones prácticas...  2010-07-05
# 2  - El tema es muy interesante y puede ser de mu...  2010-07-05
# 3  Se explica en forma ordenada y didáctica una e...  2010-07-05
# 4                                                     2010-07-05

# %%
# I can see have some missing data

df4["text"].iloc[40]
# Out:
# ''

# %%
##############################################################################

# %% [markdown]
# #### Identify the languages by myself

# %%
# !pip install langid
# Out:
# Requirement already satisfied: langid in c:\users\isanj\anaconda3\lib\site-packages (1.1.6)
# Requirement already satisfied: numpy in c:\users\isanj\anaconda3\lib\site-packages (from langid) (1.19.2)

# %%
import langid # language identification (i.e. what language is this?)

# %%
# Identified languages 

diff_languages = (df4['text']).apply(langid.classify)
diff_languages.head()
# Out:
# 0    (es, -2286.3553416728973)
# 1      (es, -2561.28048992157)
# 2     (es, -4911.551350593567)
# 3     (es, -4179.394695520401)
# 4      (en, 9.061840057373047)
# Name: text, dtype: object

# %%
# Extract just the language 
langs = diff_languages.apply(lambda tuple: tuple[0])
langs.unique()
#langs
# Out:
# array(['es', 'en', 'lt'], dtype=object)

# %%
# Count the english 
print(sum(langs== "en"))   # The result is higher "23 texts in english, against the 17 expected". I have to find out why?
# Out:
# 23

# %%
# Put everything in a list 
langs_list = list(langs)
#langs_list

# %%
# List of the indexes of all the reviews in english
res_list = [] 
for i in range(0, len(langs_list)) : 
    if langs_list[i] == str('en') : 
        res_list.append(i)
        
#res_list

# %%
# Let check for empty string in the list of texts

for i in res_list:
    if (df4["text"].iloc[i]== ''):
        print(i)
# Out:
# 4
# 40
# 45
# 67
# 70
# 108

# %% [raw]
# # I have 6 empty strings under english texts identification, that explain why I had 23 texts identified as english instead of the 17 expected

# %%
print(sum(langs=="es"))
# Out:
# 381

# %%
#  Check if any missing values in the spanish texts

for i in range(0, len(langs_list)): 
    if langs_list[i] == "es":
        if (df4["text"].iloc[i]== ''):
            print(i)
        else:
            break
print("No missing values")
# Out:
# No missing values

# %%
print(sum(langs=="lt"))
# Out:
# 1

# %%
for i in range(0, len(langs_list)):
    if langs_list[i] == "lt":
        print(df4["text"].iloc[i])
# Out:
# NO ME ENCUENTRO CAPACITADO PARA EFECTUAR ESTA REVISION. ESTA MUY LEJOS DE MI ESPECIALIZACION.

# %% [raw]
# # I don't know why this text was detected as latin by the language detector, but this text is in spanish

# %%
#####################################################################

# %%
# Length of all the text reviews
df4["length"] = df4["text"].apply(len)
df4.head()
# Out:
#    level_0 confidence evaluation  id lan orientation remarks  \
# 0        0          4          1   1  es           0
# 1        0          4          1   2  es           1
# 2        0          5          1   3  es           1
# 3        1          4          2   1  es           1
# 4        1          4          2   2  es           0
#
#                                                 text    timespan  length
# 0  - El artículo aborda un problema contingente y...  2010-07-05     575
# 1  El artículo presenta recomendaciones prácticas...  2010-07-05     618
# 2  - El tema es muy interesante y puede ser de mu...  2010-07-05    1259
# 3  Se explica en forma ordenada y didáctica una e...  2010-07-05    1350
# 4                                                     2010-07-05       0

# %%
# Visualize the length of the reviews

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
#df4["length"].plot.hist(bins=50)
#df4["length"].plot.hist(bins=100)
df4["length"].plot.hist(bins=150)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df4["length"].describe()
# Out:
# count     405.000000
# mean     1004.992593
# std       832.041880
# min         0.000000
# 25%       465.000000
# 50%       803.000000
# 75%      1272.000000
# max      6345.000000
# Name: length, dtype: float64

# %%
# # The longest review

# df4[df4["length"]==6345]["text"].iloc[0]

# %% [markdown]
# ### Text Pre-processing using NLTK

# %%
# Using spanish text from the original dataset.

# %%
df4_spanish.shape
# Out:
# (388, 9)

# %%
# Checking for missing values
df4_spanish.isnull().sum()
# Out:
# level_0        0
# confidence     2
# evaluation     0
# id             0
# lan            0
# orientation    0
# remarks        0
# text           0
# timespan       0
# dtype: int64

# %%
def cleanText(review):
    
    # split into words

    tokens = word_tokenize(review)
        
    # convert to lower case
    review_tokens = [w.lower() for w in tokens]
        
    # remove punctuation from each word
    table = str.maketrans('', '', string.punctuation)
    review_no_punct = [w.translate(table) for w in review_tokens]
    
    # remove remaining tokens that are not alphabetic
    
    review_tokens_new = [word for word in review_no_punct if word.isalpha()]
    
    # filter out stop words
    clean_token = [w for w in review_tokens_new if not w in stop_words]
    

    
    return clean_token

# %%
df4_spanish['New_text'] = (df4_spanish["text"]).apply(cleanText)

df4_spanish.head()
# Out:
# <ipython-input-47-477dbb86a53b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4_spanish['New_text'] = (df4_spanish["text"]).apply(cleanText)
#    level_0 confidence evaluation  id lan orientation remarks  \
# 0        0          4          1   1  es           0
# 1        0          4          1   2  es           1
# 2        0          5          1   3  es           1
# 3        1          4          2   1  es           1
# 4        1          4          2   2  es           0
#
#                                                 text    timespan  \
# 0  - El artículo aborda un problema contingente y...  2010-07-05
# 1  El artículo presenta recomendaciones prácticas...  2010-07-05
# 2  - El tema es muy interesante y puede ser de mu...  2010-07-05
# 3  Se explica en forma ordenada y didáctica una e...  2010-07-05
# 4                                                     2010-07-05
#
#                                             New_text
# 0  [artículo, aborda, problema, contingente, rele...
# 1  [artículo, presenta, recomendaciones, práctica...
# 2  [tema, interesante, puede, ser, mucha, ayuda, ...
# 3  [explica, forma, ordenada, didáctica, experien...
# 4                                                 []

# %%
# Lemmatization

lemmatizer = WordNetLemmatizer()
def lemm(words):
    new = []
    lemma_words = [lemmatizer.lemmatize(x) for x in words]
    new.append(lemma_words)
    return new



df4_spanish["text_lemmatized"] = (df4_spanish['New_text']).apply(lemm)

df4_spanish.head()
# Out:
# <ipython-input-48-18bf8f43ec07>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4_spanish["text_lemmatized"] = (df4_spanish['New_text']).apply(lemm)
#    level_0 confidence evaluation  id lan orientation remarks  \
# 0        0          4          1   1  es           0
# 1        0          4          1   2  es           1
# 2        0          5          1   3  es           1
# 3        1          4          2   1  es           1
# 4        1          4          2   2  es           0
#
#                                                 text    timespan  \
# 0  - El artículo aborda un problema contingente y...  2010-07-05
# 1  El artículo presenta recomendaciones prácticas...  2010-07-05
# 2  - El tema es muy interesante y puede ser de mu...  2010-07-05
# 3  Se explica en forma ordenada y didáctica una e...  2010-07-05
# 4                                                     2010-07-05
#
#                                             New_text  \
# 0  [artículo, aborda, problema, contingente, rele...
# 1  [artículo, presenta, recomendaciones, práctica...
# 2  [tema, interesante, puede, ser, mucha, ayuda, ...
# 3  [explica, forma, ordenada, didáctica, experien...
# 4                                                 []
#
#                                      text_lemmatized
# 0  [[artículo, aborda, problema, contingente, rel...
# 1  [[artículo, presenta, recomendaciones, práctic...
# 2  [[tema, interesante, puede, ser, mucha, ayuda,...
# 3  [[explica, forma, ordenada, didáctica, experie...
# 4                                               [[]]

# %%
# Seems like NLTK doesn't work well on Spanish Lemmatization

# %% [markdown]
# ### Text Pre-processing using SpaCy

# %%
import spacy
import es_core_news_sm
import spacy_spanish_lemmatizer
from spacy.lang.es.stop_words import STOP_WORDS

# %%
nlp = es_core_news_sm.load()

# %%
df4_spanish_spacy = df4[df4['lan']=='es']

# %%
# Lower case 

df4_spanish_spacy['new_text'] = df4_spanish_spacy["text"].apply(lambda x: " ".join(x.lower() for x in x.split()))
df4_spanish_spacy['new_text'].head()
# Out:
# <ipython-input-53-2420d53e4103>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4_spanish_spacy['new_text'] = df4_spanish_spacy["text"].apply(lambda x: " ".join(x.lower() for x in x.split()))
# 0    - el artículo aborda un problema contingente y...
# 1    el artículo presenta recomendaciones prácticas...
# 2    - el tema es muy interesante y puede ser de mu...
# 3    se explica en forma ordenada y didáctica una e...
# 4
# Name: new_text, dtype: object

# %%
# Build list of stopwords
stopwords = list(STOP_WORDS)
stopwords
# Out:
# ['arribaabajo',
#  'aun',
#  'emplear',
#  'que',
#  'fin',
#  'nada',
#  'entre',
#  'aproximadamente',
#  'despues',
#  'tiene',
#  'podrán',
#  'primero',
#  'indicó',
#  'tuyo',
#  'dar',
#  'vosotros',
#  'esas',
#  'mi',
#  'podria',
#  'ampleamos',
#  'nuestros',
#  'pesar',
#  'trabajamos',
#  'durante',
#  'todavía',
#  'mediante',
#  'podriais',
#  'siendo',
#  'habían',
#  'del',
#  'sabeis',
#  'habla',
#  'próximos',
#  'cierto',
#  'ayer',
#  'medio',
#  'intentan',
#  'no',
#  'mucho',
#  'claro',
#  'nos',
#  'cuántas',
#  'emplean',
#  'hasta',
#  'mios',
#  'ninguna',
#  'apenas',
#  'mientras',
#  'debe',
#  'haciendo',
#  'hoy',
#  'varios',
#  'ir',
#  'sea',
#  'nosotros',
#  'cuanto',
#  'este',
#  'partir',
#  'quiza',
#  'podeis',
#  'sabemos',
#  'esa',
#  'trabajan',
#  'tienen',
#  'han',
#  'detrás',
#  'horas',
#  'excepto',
#  'haceis',
#  'intentas',
#  'cómo',
#  'pocos',
#  'estoy',
#  'aqui',
#  'estados',
#  'pasada',
#  'mía',
#  'dos',
#  'haya',
#  'podemos',
#  'repente',
#  'podrá',
#  'cuatro',
#  'ambos',
#  'ex',
#  'saben',
#  'solamente',
#  'propia',
#  'quizas',
#  'atras',
#  'siguiente',
#  'usa',
#  'todos',
#  'nuevo',
#  'parte',
#  'segunda',
#  'tercera',
#  'existen',
#  'usan',
#  'aquél',
#  'dieron',
#  'diferente',
#  'pronto',
#  'somos',
#  'tambien',
#  'uso',
#  'uno',
#  'alli',
#  'ello',
#  'mia',
#  'yo',
#  'tengo',
#  'seis',
#  'cuantas',
#  'así',
#  'hemos',
#  'solas',
#  'unas',
#  'afirmó',
#  'comentó',
#  'deben',
#  'deprisa',
#  'aquélla',
#  'largo',
#  'llegó',
#  'pasado',
#  'hubo',
#  'además',
#  'tenido',
#  'vamos',
#  'todavia',
#  'ahí',
#  'ellos',
#  'despacio',
#  'trabaja',
#  'tuyos',
#  'cuando',
#  'intentais',
#  'mayor',
#  'poner',
#  'ti',
#  'mencionó',
#  'tuya',
#  'considera',
#  'dan',
#  'manifestó',
#  'alguno',
#  'fui',
#  'he',
#  'quiere',
#  'sola',
#  'últimos',
#  'buenos',
#  'conseguimos',
#  'eramos',
#  'decir',
#  'adelante',
#  'otras',
#  'final',
#  'toda',
#  'hacer',
#  'conocer',
#  'aquí',
#  'ese',
#  'sera',
#  'todas',
#  'como',
#  'ésta',
#  'ahora',
#  'algunos',
#  'cuál',
#  'si',
#  'vaya',
#  'soyos',
#  'mis',
#  'principalmente',
#  'quizás',
#  'delante',
#  'otra',
#  'quiénes',
#  'podriamos',
#  'quienes',
#  'trabajas',
#  'cuenta',
#  'tampoco',
#  'tú',
#  'hizo',
#  'dejó',
#  'ser',
#  'dia',
#  'eran',
#  'misma',
#  'ejemplo',
#  'suyas',
#  'saber',
#  'ahi',
#  'bueno',
#  'pudo',
#  'pueden',
#  'trabajo',
#  'quizá',
#  'peor',
#  'verdadero',
#  'mías',
#  'otros',
#  'nadie',
#  'trabajais',
#  'éstos',
#  'había',
#  'qué',
#  'consiguen',
#  'última',
#  'hacia',
#  'primera',
#  'podría',
#  'ver',
#  'sin',
#  'enseguida',
#  'segundo',
#  'días',
#  'nuestro',
#  'habia',
#  'pueda',
#  'quedó',
#  'solos',
#  'otro',
#  'esta',
#  'total',
#  'enfrente',
#  'muchos',
#  'tendrán',
#  'sabe',
#  'veces',
#  'muchas',
#  'usais',
#  'nueva',
#  'dias',
#  'ningún',
#  'habrá',
#  'ocho',
#  'aquel',
#  'parece',
#  'cosas',
#  'lo',
#  'alguna',
#  'da',
#  'través',
#  'usas',
#  'empleas',
#  'ya',
#  'le',
#  'aquello',
#  'cualquier',
#  'consigo',
#  'qeu',
#  'esto',
#  'las',
#  'para',
#  'cual',
#  'lado',
#  'intenta',
#  'tenemos',
#  'mucha',
#  'aunque',
#  'consideró',
#  'ciertos',
#  'paìs',
#  'haber',
#  'vuestros',
#  'dicho',
#  'encuentra',
#  'pocas',
#  'poder',
#  'cierta',
#  'ciertas',
#  'una',
#  'mismas',
#  'sean',
#  'siete',
#  'llevar',
#  'algo',
#  'sabes',
#  'voy',
#  'sois',
#  'teneis',
#  'vuestra',
#  'aún',
#  'contigo',
#  'último',
#  'el',
#  'hablan',
#  'tarde',
#  'informo',
#  'anterior',
#  'dio',
#  'estos',
#  'gueno',
#  'son',
#  'breve',
#  'día',
#  'éste',
#  'propias',
#  'propio',
#  'ella',
#  'eras',
#  'mal',
#  'unos',
#  'algunas',
#  'embargo',
#  'verdad',
#  'añadió',
#  'antano',
#  'haces',
#  'quien',
#  'tenía',
#  'acuerdo',
#  'tenga',
#  'arriba',
#  'cuáles',
#  'ése',
#  'tan',
#  'buen',
#  'suya',
#  'tuyas',
#  'mas',
#  'nuestras',
#  'la',
#  'los',
#  'vosotras',
#  'encima',
#  'bien',
#  'pais',
#  'diferentes',
#  'puedo',
#  'en',
#  'ningunos',
#  'podrian',
#  'tras',
#  'estas',
#  'buena',
#  'estais',
#  'respecto',
#  'éstas',
#  'salvo',
#  'creo',
#  'muy',
#  'están',
#  'todo',
#  'también',
#  'empleo',
#  'trata',
#  'tus',
#  'mejor',
#  'de',
#  'puede',
#  'dicen',
#  'algún',
#  'últimas',
#  'fue',
#  'aquellos',
#  'desde',
#  'tal',
#  'mio',
#  'su',
#  'lejos',
#  'verdadera',
#  'es',
#  'tuvo',
#  'agregó',
#  'cinco',
#  'tendrá',
#  'dentro',
#  'realizar',
#  'aseguró',
#  'dónde',
#  'buenas',
#  'varias',
#  'pero',
#  'hecho',
#  'ninguno',
#  'estan',
#  'intentamos',
#  'nuestra',
#  'allí',
#  'será',
#  'alrededor',
#  'conseguir',
#  'ésa',
#  'igual',
#  'con',
#  'nunca',
#  'os',
#  'usamos',
#  'estar',
#  'está',
#  'hace',
#  'tu',
#  'general',
#  'porque',
#  'hay',
#  'poca',
#  'dijeron',
#  'propios',
#  'consigues',
#  'dado',
#  'vuestro',
#  'un',
#  'cuántos',
#  'mismos',
#  'valor',
#  'me',
#  'aquéllos',
#  'cerca',
#  'ni',
#  'incluso',
#  'debajo',
#  'mismo',
#  'cada',
#  'aquella',
#  'bajo',
#  'asi',
#  'gran',
#  'primer',
#  'cuanta',
#  'quién',
#  'debido',
#  'supuesto',
#  'sido',
#  'por',
#  'realizó',
#  'ésas',
#  'míos',
#  'cuándo',
#  'estuvo',
#  'próximo',
#  'cuánto',
#  'ningunas',
#  'ante',
#  'hacen',
#  'vez',
#  'ha',
#  'señaló',
#  'antes',
#  'estaban',
#  'sus',
#  'nosotras',
#  'lleva',
#  'informó',
#  'ellas',
#  'van',
#  'explicó',
#  'contra',
#  'después',
#  'conmigo',
#  'hicieron',
#  'pues',
#  'fuimos',
#  'sigue',
#  'bastante',
#  'al',
#  'serán',
#  'sobre',
#  'estamos',
#  'sería',
#  'primeros',
#  'actualmente',
#  'tiempo',
#  'entonces',
#  'dice',
#  'segun',
#  'posible',
#  'nuevos',
#  'siempre',
#  'cuantos',
#  'casi',
#  'fuera',
#  'estará',
#  'raras',
#  'menudo',
#  'se',
#  'demasiado',
#  'momento',
#  'mí',
#  'sino',
#  'tener',
#  'hacerlo',
#  'te',
#  'sólo',
#  'menos',
#  'soy',
#  'esos',
#  'va',
#  'empleais',
#  'manera',
#  'mias',
#  'modo',
#  'existe',
#  'ademas',
#  'mío',
#  'grandes',
#  'consigue',
#  'estado',
#  'adrede',
#  'hacemos',
#  'eres',
#  'usar',
#  'podrias',
#  'cuales',
#  'eso',
#  'poco',
#  'suyo',
#  'realizado',
#  'luego',
#  'trabajar',
#  'más',
#  'fueron',
#  'expresó',
#  'intentar',
#  'cuánta',
#  'donde',
#  'junto',
#  'les',
#  'antaño',
#  'temprano',
#  'vais',
#  'queremos',
#  'intento',
#  'nuevas',
#  'detras',
#  'él',
#  'sé',
#  'usted',
#  'según',
#  'ésos',
#  'tres',
#  'demás',
#  'tanto',
#  'solo',
#  'ustedes',
#  'sí',
#  'lugar',
#  'hago',
#  'aquéllas',
#  'proximo',
#  'era',
#  'estaba',
#  'dijo',
#  'vuestras',
#  'podrían',
#  'ultimo',
#  'aquellas']

# %%
# Remove stop words

df4_spanish_spacy['new_text'] = df4_spanish_spacy['new_text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop_words))

df4_spanish_spacy['new_text'].head()
# Out:
# <ipython-input-55-1f10b92448e4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4_spanish_spacy['new_text'] = df4_spanish_spacy['new_text'].apply(lambda x: " ".join(x for x in x.split() if x not in stop_words))
# 0    - artículo aborda problema contingente relevan...
# 1    artículo presenta recomendaciones prácticas de...
# 2    - tema interesante puede ser mucha ayuda guía ...
# 3    explica forma ordenada didáctica experiencia u...
# 4
# Name: new_text, dtype: object

# %%
# Remove punctuations

df4_spanish_spacy['new_text'] = df4_spanish_spacy['new_text'].str.replace('[^\w\s]','')

df4_spanish_spacy['new_text'].head()
# Out:
# <ipython-input-56-103287184ed1>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4_spanish_spacy['new_text'] = df4_spanish_spacy['new_text'].str.replace('[^\w\s]','')
# 0     artículo aborda problema contingente relevant...
# 1    artículo presenta recomendaciones prácticas de...
# 2     tema interesante puede ser mucha ayuda guía i...
# 3    explica forma ordenada didáctica experiencia u...
# 4
# Name: new_text, dtype: object

# %%
# Lemmatization
def lemm(review):
    nlp=spacy.load("es_core_news_sm")
    doc = nlp(str(review))
    return " ".join([token.lemma_ for token in doc])

df4_spanish_spacy['Lemma_text'] = df4_spanish_spacy['new_text'].apply(lemm)
df4_spanish_spacy.head()
# Out:
# <ipython-input-57-d07f28faf361>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df4_spanish_spacy['Lemma_text'] = df4_spanish_spacy['new_text'].apply(lemm)
#    level_0 confidence evaluation  id lan orientation remarks  \
# 0        0          4          1   1  es           0
# 1        0          4          1   2  es           1
# 2        0          5          1   3  es           1
# 3        1          4          2   1  es           1
# 4        1          4          2   2  es           0
#
#                                                 text    timespan  length  \
# 0  - El artículo aborda un problema contingente y...  2010-07-05     575
# 1  El artículo presenta recomendaciones prácticas...  2010-07-05     618
# 2  - El tema es muy interesante y puede ser de mu...  2010-07-05    1259
# 3  Se explica en forma ordenada y didáctica una e...  2010-07-05    1350
# 4                                                     2010-07-05       0
#
#                                             new_text  \
# 0   artículo aborda problema contingente relevant...
# 1  artículo presenta recomendaciones prácticas de...
# 2   tema interesante puede ser mucha ayuda guía i...
# 3  explica forma ordenada didáctica experiencia u...
# 4
#
#                                           Lemma_text
# 0    artículo abordo problema contingente relevan...
# 1  artículo presentar recomendación práctico desa...
# 2    tema interesante poder ser mucho ayuda guío ...
# 3  explicar forma ordenado didáctico experiencia ...
# 4

# %%
#Spacy seems to be better for spanish lemmatization

# %%
from spacy import displacy

# %%
# Lemmatization
def lemm(review):
    nlp=spacy.load("es_core_news_sm")
    doc = nlp(str(review))
    return " ".join([token.lemma_ for token in doc])

df4_spanish_spacy['Lemma_text'] = df4_spanish_spacy['new_text'].apply(lemm)
df4_spanish_spacy.head()
